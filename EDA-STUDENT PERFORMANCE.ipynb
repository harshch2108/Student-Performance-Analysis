# %% [markdown]
# # EDA-STUDENT PERFORMANCE

# %% [markdown]
# * The dataset is related to student performance and attributes in secondary education. Here's a general introduction based on the columns present in the DataFrame:
# *
# This dataset contains information about students in secondary education, including demographic details, family background, educational support, lifestyle choices, and academic performanc
#
# * . Each row represents a unique student, and the columns provide various attributes and characteristics associated with them.20).

# %%
#import all the libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('student-por.csv')
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
df.dtypes
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
# ...

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %% [markdown]
# * There is no null values

# %% [markdown]
# # Separated categorical and numerical columns

# %%
cats=['school','sex','address','formsize','Pstatus','Mjob','Fjob']
nums=['age','Medu','Fedu','famrel','freetime','goout','Walc','health','absences','G1','G2','Dalc']

# %%
cats
# Out:
# ['school', 'sex', 'address', 'formsize', 'Pstatus', 'Mjob', 'Fjob']

# %%
nums
# Out:
# ['age',
#  'Medu',
#  'Fedu',
#  'famrel',
#  'freetime',
#  'goout',
#  'Walc',
#  'health',
#  'absences',
#  'G1',
#  'G2',
#  'Dalc']

# %% [markdown]
# # UNIVARIATE ANALYSIS

# %%
df['school'].value_counts()
# Out:
# school
# GP    423
# MS    226
# Name: count, dtype: int64

# %%
# COUNTPLOT
plt.figure(figsize=(10,5))
sns.countplot(x=df['school'],palette='pastel')
plt.title("Distribution of schools")
plt.xlabel("School")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# * **GP has higher no. of students**

# %%
sns.histplot(df['age'],bins=10,kde=True,palette='salmon')
plt.show()

# %% [markdown]
# * **Most of the students are between the age-group 15-18 years**
# * **Skewed distribution**

# %%
sns.countplot(x = 'address', data=df, palette = 'dark')
plt.show()

# %% [markdown]
# * **The majority of students comes from urban region**

# %%
df['reason'].unique()
# Out:
# array(['course', 'other', 'home', 'reputation'], dtype=object)

# %%
df['reason'].value_counts()
# Out:
# reason
# course        285
# home          149
# reputation    143
# other          72
# Name: count, dtype: int64

# %%
reason =df['reason'].value_counts()
plt.pie(reason,autopct="%1.1f%%",labels=reason.index,shadow=True,explode=(0,0.01,0,0.1))
plt.show()

# %% [markdown]
# * **Common reason is to join the course**

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
act = df['activities'].value_counts()

# %%
act
# Out:
# activities
# no     334
# yes    315
# Name: count, dtype: int64

# %%
plt.pie(act , labels=act.index,autopct="%1.1f%%",shadow=True,explode=(0,0.1))
plt.show()

# %% [markdown]
# * **48.5% are performing**

# %%
weekly_alcohol = df['Walc'].value_counts()
weekly_alcohol
# Out:
# Walc
# 1    247
# 2    150
# 3    120
# 4     87
# 5     45
# Name: count, dtype: int64

# %%
plt.pie(weekly_alcohol,labels = weekly_alcohol.index,autopct="%1.1f%%",shadow=True,startangle=90)
plt.show()

# %% [markdown]
# * **6.9% (45) students have 5 times alcohol consumption per week**

# %%
daily=df["Dalc"].value_counts()
daily
# Out:
# Dalc
# 1    451
# 2    121
# 3     43
# 5     17
# 4     17
# Name: count, dtype: int64

# %%
plt.pie(daily,labels = daily.index,autopct="%1.1f%%",shadow=True,startangle=90)
plt.show()

# %% [markdown]
# * **69.5% students drinks alcohol daily.**

# %% [markdown]
# # BIVARIATE ANALYSIS

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
plt.figure(figsize = (12, 6))
plt.subplot(1, 2, 1)
sns.countplot(x = 'Medu', data=df, palette = 'Set2')
plt.xlabel('Mother education level')
plt.ylabel('count')
plt.title('Mother education level dist')


plt.subplot(1, 2, 2)
sns.countplot(x = 'Fedu', data=df, palette = 'Set2')
plt.xlabel("Father education level")
plt.ylabel("count")
plt.title("Father education level dist")

plt.show()

# %% [markdown]
# * **Mothers are mode educated in terms of higher education as compared to fathers**

# %%
sns.barplot(x = 'studytime', y = 'G3', data=df,palette='Set2')
plt.show()

# %% [markdown]
# * **If a student study for an hour than the marks scored on an average  is 11**
# * **Iif a student study for two hours than the marks scored on an average  is12**
# * **If a student study for three hours than the marks scored on an average  is 13**rks

# %%
df.G3.unique()
# Out:
# array([11, 12, 14, 13, 17, 15,  7, 10, 16,  9,  8, 18,  6,  0,  1,  5, 19],
#       dtype=int64)

# %%
sns.barplot(x = 'studytime', y = 'G2', data=df,palette='Set2')
plt.show()

# %%
sns.barplot(x = 'internet', y = 'G3', data=df,palette='Set2')
plt.show()

# %% [markdown]
# * **Students using internet are scoring 12 marks**
# * **Students not using internet are scoring 11 marks**

# %% [markdown]
# # **MULTIVARIATE ANALYSIS**

# %%
sns.barplot(x = 'sex', y = 'G3', hue = 'address', data=df, palette = 'Set2')
plt.show()

# %% [markdown]
# * **North urban males and females are getting higher average marks**

# %%
num_cols = ['age', 'traveltime', 'studytime', 'absences', 'G1', 'G2', 'G3']

sns.boxplot(data = df[num_cols], palette = 'Set2')
plt.show()

# %% [markdown]
# * **median age is 17**
# * **Here are many outliers**

# %%
corr = df.corr(numeric_only = True)

# %%
plt.figure(figsize = (12, 10))
sns.heatmap(corr, annot=True, cmap = "coolwarm", fmt = ".2f")
plt.show()

# %%
num_cols = ['age', 'traveltime', 'studytime', 'absences', 'G1', 'G2', 'G3']

sns.violinplot(data = df[num_cols], palette = 'Set2')
plt.show()
